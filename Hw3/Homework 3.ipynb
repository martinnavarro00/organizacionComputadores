# %% [markdown]
# # Homework 3

# %% [markdown]
# ### Linux Tutorial: Understanding Memory Management

# %% [markdown]
# Total physical memory

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.48.34.png](attachment:Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.48.34.png)

# %% [markdown]
# Virtual memory

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.48.55.png](attachment:Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.48.55.png)

# %% [markdown]
# Memory Over-allocation

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.49.32.png](attachment:Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2017.49.32.png)

# %% [markdown]
# Keeping page cache

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2018.01.56.png](attachment:Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2018.01.56.png)

# %% [markdown]
# Active and Inactive memory

# %% [markdown]
# ![Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2018.08.32.png](attachment:Captura%20de%20Pantalla%202022-04-20%20a%20la%28s%29%2018.08.32.png)
